# %%
def surface_to_string(surface):
    """Convert a pygame surface into string"""
    return pygame.image.tostring(surface, 'RGB')

def cvimage_to_pygame2(image):
    """Convert cvimage into a pygame image"""
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return pygame.image.frombuffer(image.tostring(), image.shape[1::-1],
                                   "RGB")


def pygame_to_cvimage(surface):
    """Convert a pygame surface into a cv image"""
    cv_image = cv22.CreateImageHeader(surface.get_size(), cv2.IPL_DEPTH_8U, 3)
    image_string = surface_to_string(surface)
    cv2.SetData(cv_image, image_string)
    return cv_image

def cvimage_to_pygame(image):
    """Convert cvimage into a pygame image"""
    image_rgb = cv2.CreateMat(image.height, image.width, cv2.CV_8UC3)
    cv2.CvtColor(image, image_rgb, cv2.CV_BGR2RGB)
    return pygame.image.frombuffer(image.tostring(), cv2.GetSize(image_rgb),
                                   "RGB")

def cvimage_grayscale(cv_image):
    """Converts a cvimage into grayscale"""
    grayscale = cv2.CreateImage(cv2.GetSize(cv_image), 8, 1)
    cv2.CvtColor(cv_image, grayscale, cv2.CV_RGB2GRAY)
    return grayscale

# %%
from pygame.locals import *
import pygame
import cv2
import sys
import numpy as np
import pygame_menu

pygame.init()
surface = pygame.display.set_mode((600, 400))


def start_the_game():
    start()
    pass

menu = pygame_menu.Menu(300, 400, 'Welcome',
                       theme=pygame_menu.themes.THEME_BLUE)

#menu.add_selector('Difficulty :', [('Hard', 1), ('Easy', 2)], onchange=set_difficulty)
menu.add_button('Play', start_the_game)
menu.add_button('Quit', pygame_menu.events.EXIT)

menu.mainloop(surface)
# Out:
# <rect(0, 0, 100, 100)>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-10-f9850832f583> in <module>
#      21 menu.add_button('Quit', pygame_menu.events.EXIT)
#      22
# ---> 23 menu.mainloop(surface)
#
# ~\Anaconda3\lib\site-packages\pygame_menu\menu.py in mainloop(self, surface, bgfun, disable_loop, fps_limit)
#    1687             # If loop, gather events by Menu and draw the background function, if this method
#    1688             # returns true then the mainloop will break
# -> 1689             self.update(pygame.event.get())
#    1690
#    1691             if not self.is_enabled() or disable_loop:
#
# ~\Anaconda3\lib\site-packages\pygame_menu\menu.py in update(self, events)
#    1622                         new_event.dict['origin'] = self._current._scroll.to_real_position((0, 0))
#    1623                         new_event.pos = self._current._scroll.to_world_position(event.pos)
# -> 1624                         selected_widget.update((new_event,))  # This widget can change the current Menu to a submenu
#    1625                         updated = True  # It is updated
#    1626                         break
#
# ~\Anaconda3\lib\site-packages\pygame_menu\widgets\widget\button.py in update(self, events)
#     119                 self.sound.play_click_mouse()
#     120                 if self._rect.collidepoint(*event.pos):
# --> 121                     self.apply()
#     122                     updated = True
#     123
#
# ~\Anaconda3\lib\site-packages\pygame_menu\widgets\core\widget.py in apply(self, *args)
#     306             except ValueError:
#     307                 pass
# --> 308             return self._on_return(*args, **self._kwargs)
#     309
#     310     def change(self, *args):
#
# <ipython-input-10-f9850832f583> in start_the_game()
#      11
#      12 def start_the_game():
# ---> 13     start()
#      14     pass
#      15
#
# <ipython-input-9-d868019d0d90> in start()
#      70
#      71
# ---> 72             gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      73             faces = faceClassif.detectMultiScale(gray, 1.3, 5)
#      74
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-52oirelq\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
def start():
    camara = 'http://192.168.1.51:4747/video'
    camera = cv2.VideoCapture(camara)
    pygame.init()
    pygame.display.set_caption("OpenCV camera stream on Pygame")
    screen = pygame.display.set_mode([480,640])



    faceClassif = cv2.CascadeClassifier('haarcascade_frontalface_alt.xml')

    class Bolita(pygame.sprite.Sprite):
        def __init__(self):
            pygame.sprite.Sprite.__init__(self)
            self.image = pygame.image.load('bolita.png')
            self.image = pygame.transform.scale(self.image, (100,100))
            self.rect = self.image.get_rect()
            print(self.rect)
            self.rect.centerx = WIDTH / 2
            self.rect.centery = HEIGHT / 2
            self.speed = [0.2, -0.2]

        def actualizar(self, time):
            self.rect.centerx += self.speed[0] * time
            self.rect.centery += self.speed[1] * time
            if self.rect.left <= 0 or self.rect.right >= WIDTH:
                self.speed[0] = -self.speed[0]
                self.rect.centerx += self.speed[0] * time
            if self.rect.top <= 0 or self.rect.bottom >= HEIGHT:
                self.speed[1] = -self.speed[1]
                self.rect.centery += self.speed[1] * time

    #         if pygame.sprite.collide_rect(self, pala_jug):
    #             self.speed[0] = -self.speed[0]
    #             self.rect.centerx += self.speed[0] * time

    class cabeza(pygame.sprite.Sprite):
        def __init__(self, rect):
            pygame.sprite.Sprite.__init__(self)
            self.rect = rect
            self.rect.centerx = rect.x
            self.rect.centery = HEIGHT / 2
            self.speed = [0.2, -0.2]

    WIDTH = 480
    HEIGHT = 640
    clock = pygame.time.Clock()

    # class Bolita2: 
    #     image = 'bolita.png'
    #     size  = (100,100)
    #     x = 50
    #     y = 50
    #     def position(self):
    #         return (self.x, self.y)


    # bolita = Bolita()

    try:
        bola = Bolita()

        while True:

            ret, frame = camera.read()    
            screen.fill([0, 0, 0])

            frame = cv2.rotate(frame, cv2.ROTATE_90_COUNTERCLOCKWISE)
            frame = cv2.flip(frame, 1) 


            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            faces = faceClassif.detectMultiScale(gray, 1.3, 5)

            for (x,y,w,h) in faces:
                cv2.rectangle(frame, (x,y),(x+w,y+h),(0,255,0),2)
    #             bolita.x = x 
    #             bolita.y = y + h/2



            cv2.imshow('frame',frame) 



            time = clock.tick(120)

            screen.blit(cvimage_to_pygame2(frame), (0, 0))

            bola.actualizar(time)
            screen.blit(bola.image, bola.rect)
    #         img_bolita = pygame.image.load(bolita.image)

    #         img_bolita = pygame.transform.scale(img_bolita, bolita.size)

    #         screen.blit(img_bolita, bolita.position())

            pygame.display.update()

            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    camera.release()
                    sys.exit(0)
                elif event.type == KEYDOWN:
                    if event.key == K_ESCAPE or event.key == K_q:
                        sys.exit(0)
                        camera.release()

    except (KeyboardInterrupt, SystemExit):
        pygame.quit()
        camera.release()
        cv2.destroyAllWindows()

# %%
# !pip install boto3

# %%
import boto3
import json
